# %% [markdown]
# # Analyzing Car Reviews with LLMs

# %% [markdown]
# 1. Used a pre-trained LLM to classify the sentiment of car reviews
# 2. Evaluated the classification accuracy, BLEU score
# 3. Summarize reviews

# %%
i
